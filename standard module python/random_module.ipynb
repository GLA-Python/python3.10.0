# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14988/902377030.py in <module>
# ----> 1 reload(math)
#
# NameError: name 'reload' is not defined
