# %%
"Positive Integer pairse"

# %%
P = int(input())
X = int(input())

for i in range((P//2)+1):  # if we use loop upto P repeat the vice versa condition 
    j = P - i
    if i ^ j == X:
        print(i, j)
# Out:
# 48 52
